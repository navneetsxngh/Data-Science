# %%
import pandas as pd

# %% [markdown]
# # Pandas question set (50) — dataset: `titanic - titanic.csv`
#
# This notebook contains **50 pandas-focused questions** (basic → intermediate → advanced) that reference columns in the Titanic dataset (`PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked`).
#
# For each question there is an empty cell where you can implement the solution (or use the cell below to run exploratory code).
#
# **How to use**
# - Run the first cell to load the dataset (`DATA_PATH` is set to the uploaded file).
# - Work through each question in order. Code cells are provided after each question for your answers.

# %% [markdown]
# **Question:** 1. Read the CSV into a DataFrame and display the first 5 rows.

# %%
# Write your solution here

# %% [markdown]
# **Question:** 2. Show the number of rows and columns in the DataFrame.

# %%
# Write your solution here

# %% [markdown]
# **Question:** 3. Display the data types of all columns and the total memory usage.

# %%
# Write your solution here

# %% [markdown]
# **Question:** 4. Show basic summary statistics (count, mean, std, min, 25%, 50%, 75%, max) for numerical columns.

# %%
# Write your solution here

# %% [markdown]
# **Question:** 5. Use `info()` to list non-null counts per column — which columns contain missing values?

# %%
# Write your solution here

# %% [markdown]
# **Question:** 6. Select only the `Name`, `Sex`, `Age` and `Fare` columns into a new DataFrame.

# %%
# Write your solution here

# %% [markdown]
# **Question:** 7. Filter the DataFrame to show only female passengers.

# %%
# Write your solution here

# %% [markdown]
# **Question:** 8. Filter to passengers who survived (`Survived == 1`) and display the first 10.

# %%
# Write your solution here

# %% [markdown]
# **Question:** 9. Get the unique values and counts for the `Embarked` column (use `value_counts`).

# %%
# Write your solution here

# %% [markdown]
# **Question:** 10. Sort the DataFrame by `Fare` descending and show the top 5 fare-paying passengers.

# %%
# Write your solution here

# %% [markdown]
# **Question:** 11. Rename the `Pclass` column to `PassengerClass`.

# %%
# Write your solution here

# %% [markdown]
# **Question:** 12. Create a boolean mask for passengers older than 60 and count how many match it.

# %%
# Write your solution here

# %% [markdown]
# **Question:** 13. Drop the `Ticket` column from the DataFrame (inplace or by assignment).

# %%
# Write your solution here

# %% [markdown]
# **Question:** 14. Convert the `Sex` column to lowercase strings (if not already) using vectorized string ops.

# %%
# Write your solution here

# %% [markdown]
# **Question:** 15. Save a subset (e.g., only `PassengerId`, `Name`, `Survived`) to a new CSV file.

# %%
# Write your solution here

# %% [markdown]
# **Question:** 16. Count survivors and non-survivors by `Pclass` using `groupby` + `size` or `value_counts`.

# %%
# Write your solution here

# %% [markdown]
# **Question:** 17. Compute average `Age` for survivors vs non-survivors.

# %%
# Write your solution here

# %% [markdown]
# **Question:** 18. Create a new column `FamilySize = SibSp + Parch + 1` and show its distribution.

# %%
# Write your solution here

# %% [markdown]
# **Question:** 19. Fill missing `Age` values with the median age. Implement both `fillna` and `transform` solutions.

# %%
# Write your solution here

# %% [markdown]
# **Question:** 20. Extract the passenger title (Mr, Mrs, Miss, etc.) from the `Name` column using string methods or regex and show counts per title.

# %%
# Write your solution here

# %% [markdown]
# **Question:** 21. Create age bins (0–12 child, 13–19 teen, 20–35 young adult, 36–60 adult, 61+ senior) and compute survival rate per bin.

# %%
# Write your solution here

# %% [markdown]
# **Question:** 22. One-hot encode the `Embarked` column (create dummy variables).

# %%
# Write your solution here

# %% [markdown]
# **Question:** 23. Convert `Sex` to a numeric column (`male` = 0, `female` = 1) using `map` or `replace`.

# %%
# Write your solution here

# %% [markdown]
# **Question:** 24. Use `.query()` to find passengers in 1st class with `Fare` > 100.

# %%
# Write your solution here

# %% [markdown]
# **Question:** 25. Use `pivot_table` to compute mean `Fare` for each combination of `Pclass` and `Sex`.

# %%
# Write your solution here

# %% [markdown]
# **Question:** 26. Group by `PassengerClass` and calculate multiple aggregations: count of passengers, mean fare, median age. Use named aggregations.

# %%
# Write your solution here

# %% [markdown]
# **Question:** 27. Identify passengers with duplicate `Ticket` values (suggesting shared tickets) and list tickets with the highest counts.

# %%
# Write your solution here

# %% [markdown]
# **Question:** 28. Using `str` methods, find how many `Cabin` entries start with the letter 'C'.

# %%
# Write your solution here

# %% [markdown]
# **Question:** 29. Create a column `IsAlone` that is `True` if `FamilySize == 1` else `False`, and compare survival rate of alone vs not-alone passengers.

# %%
# Write your solution here

# %% [markdown]
# **Question:** 30. Replace the missing `Embarked` entries with the mode of that column.

# %%
# Write your solution here

# %% [markdown]
# **Question:** 31. Use `nlargest`/`nsmallest` to find the top 3 and bottom 3 passengers by `Fare`.

# %%
# Write your solution here

# %% [markdown]
# **Question:** 32. Create a cross-tab (contingency table) of `Pclass` vs `Survived` (counts and normalized percentages).

# %%
# Write your solution here

# %% [markdown]
# **Question:** 33. Use `astype('category')` on `Pclass`, `Sex`, and `Embarked` — show how memory usage changes.

# %%
# Write your solution here

# %% [markdown]
# **Question:** 34. Create a new column `FarePerPerson = Fare / FamilySize` and display summary stats.

# %%
# Write your solution here

# %% [markdown]
# **Question:** 35. Use `sample()` to return a reproducible random sample of 10 rows.

# %%
# Write your solution here

# %% [markdown]
# **Question:** 36. Using `groupby` + `transform`, impute missing `Age` values by the median age of passengers with the same title (extracted from `Name`).

# %%
# Write your solution here

# %% [markdown]
# **Question:** 37. For the `Cabin` column that may contain multiple cabin numbers like 'C123 C125', split on whitespace and use `.explode()` to create a row per cabin — then compute the most common deck letter (first char).

# %%
# Write your solution here

# %% [markdown]
# **Question:** 38. Build a method-chaining pipeline (no intermediate variables) that: drops `Ticket`, fills `Embarked` mode, encodes `Sex`, creates `FamilySize`, bins `Age`, and returns the top 5 rows. Use `assign`, `pipe`, and chained ops.

# %%
# Write your solution here

# %% [markdown]
# **Question:** 39. Create a pivot table with multi-index rows (e.g., `Pclass`, `Sex`) and columns `Survived` showing counts and normalize across rows.

# %%
# Write your solution here

# %% [markdown]
# **Question:** 40. Use `apply` with a custom function to compute a `TitleRiskScore` from title (e.g., map rare titles to higher risk) — show when `apply` is appropriate vs vectorized `map`.

# %%
# Write your solution here

# %% [markdown]
# **Question:** 41. Compute the correlation matrix for numeric features (`Age`, `Fare`, `SibSp`, `Parch`, `FamilySize`) and identify the strongest positive and negative correlations with `Survived`.

# %%
# Write your solution here

# %% [markdown]
# **Question:** 42. Demonstrate using `.agg()` with different aggregation functions per column plus a custom lambda (e.g., `{'Fare':['mean','max'], 'Age': lambda s: s.isna().mean()}`) and explain the output shape.

# %%
# Write your solution here

# %% [markdown]
# **Question:** 43. Create a rolling window aggregate (e.g., rolling mean of Fare) after sorting by `Fare` — explain why ordering matters and show the result for window=5.

# %%
# Write your solution here

# %% [markdown]
# **Question:** 44. Using `pd.cut`, create quantile-based bins for `Fare` (quartiles) and compute survival rate per fare-quantile.

# %%
# Write your solution here

# %% [markdown]
# **Question:** 45. Convert the DataFrame to a long format with `melt` for columns `SibSp` and `Parch`, then pivot back — explain when melt/pivot are useful.

# %%
# Write your solution here

# %% [markdown]
# **Question:** 46. Use `merge` to join this dataset with a synthetic DataFrame containing `PassengerId` → `CustomLabel` (show left, right, inner joins and effect on row counts).

# %%
# Write your solution here

# %% [markdown]
# **Question:** 47. Optimize the DataFrame for memory and speed: cast appropriate columns to `category`, downcast numeric dtypes, and report memory usage before and after.

# %%
# Write your solution here

# %% [markdown]
# **Question:** 48. Use `df.eval()` and `df.query()` to create `IsSenior = Age >= 61` and then filter rows using a single `query` string that references this new variable (show how `eval` can speed up complex expressions).

# %%
# Write your solution here

# %% [markdown]
# **Question:** 49. Create a reproducible scikit-learn pipeline-ready feature DataFrame: select numeric features, impute missing values, one-hot encode categoricals, and output `X` ready for model training — implement using pandas only (show final shape and column names).

# %%
# Write your solution here

# %% [markdown]
# **Question:** 50. Write a function that accepts the filename (path), reads the CSV with explicit `dtype` hints and `usecols`, handles missing values, and returns a cleaned DataFrame — show how to unit test this function using a small hard-coded sample `pd.DataFrame`.

# %%
# Write your solution here
